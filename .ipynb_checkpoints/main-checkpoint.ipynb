# %%
import pandas as pd
import numpy as np
import time

from datetime import timedelta, datetime
import requests

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %%
Company_list = ['3MINDIA','AARTIDRUGS','AARTIIND','AAVAS','ABB','ABCAPITAL','ABFRL','ACC','ACCELYA','ACE','ADANIENT',
                'ADANIPORTS','ADFFOODS','ADVENZYMES','AEGISCHEM','AHLUCONT','AIAENG','AJANTPHARM','AKZOINDIA','ALEMBICLTD',
                'ALKEM','ALKYLAMINE','ALLCARGO','ALOKINDS','AMARAJABAT','AMBER','AMBUJACEM','AMRUTANJAN','ANURAS','APARINDS',
                'APLAPOLLO','APLLTD','APOLLOHOSP','APOLLOPIPE','APOLLOTYRE','ARVIND','ARVINDFASN','ASAHIINDIA','ASHIANA',
                'ASHOKA','ASHOKLEY','ASIANPAINT','ASTEC','ASTERDM','ASTRAL','ASTRAZEN','ATFL','ATUL','AUBANK','AUROPHARMA',
                'AUTOAXLES','AVANTIFEED','AXISBANK','BAJAJ-AUTO','BAJAJCON','BAJAJELEC','BAJAJFINSV','BAJAJHLDNG','BAJFINANCE',
                'BALAMINES','BALKRISIND','BALMLAWRIE','BALRAMCHIN','BANARISUG','BANDHANBNK','BANKBARODA','BANKINDIA','BASF',
                'BATAINDIA','BBTC','BDL','BECTORFOOD','BEL','BEML','BEPL','BERGEPAINT','BHARATFORG','BHARATRAS','BHARTIARTL',
                'BHEL','BIOCON','BIRLACORPN','BLUEDART','BLUESTARCO','BOMDYEING','BOSCHLTD','BPCL','BRIGADE','BRITANNIA','BSE',
                'BSOFT','CAMLINFINE','CANBK','CANFINHOME','CAPACITE','CAPLIPOINT','CARBORUNIV','CARERATING','CASTROLIND','CCL',
                'CDSL','CEATLTD','CENTRALBK','CENTRUM','CENTURYPLY','CENTURYTEX','CERA','CESC','CGCL','CHALET','CHAMBLFERT',
                'CHEMCON','CHENNPETRO','CHOLAFIN','CHOLAHLDNG','CIPLA','COALINDIA','COCHINSHIP','COFORGE','COLPAL','CONCOR',
                'CONFIPET','COROMANDEL','CRAFTSMAN','CREDITACC','CRISIL','CROMPTON','CSBBANK','CUB','CUMMINSIND','CYIENT',
                'DAAWAT','DABUR','DALBHARAT','DALMIASUG','DBCORP','DBL','DCAL','DCBBANK','DCMSHRIRAM','DEEPAKNTR','DELTACORP',
                'DEN','DFMFOODS','DHAMPURSUG','DHANI','DHANUKA','DIAMONDYD','DISHTV','DIVISLAB','DIXON','DLF','DMART','DOLLAR',
                'DRREDDY','EASEMYTRIP','EDELWEISS','EICHERMOT','EIDPARRY','EIHOTEL','ELGIEQUIP','EMAMILTD','ENDURANCE',
                'ENGINERSIN','EPL','EQUITAS','EQUITASBNK','ERIS','ESABINDIA','ESCORTS','EVEREADY','EXIDEIND','FACT',
                'FCONSUMER','FDC','FEDERALBNK','FILATEX','FINCABLES','FINEORG','FINPIPE','FMGOETZE','FORTIS','FRETAIL',
                'FSL','GABRIEL','GAEL','GAIL','GALAXYSURF','GANECOS','GARFIBRES','GATI','GENUSPOWER','GEOJITFSL','GEPIL',
                'GESHIP','GET&D','GHCL','GICRE','GILLETTE','GLAND','GLAXO','GLENMARK','GMDCLTD','GMMPFAUDLR','GMRINFRA',
                'GNFC','GODFRYPHLP','GODREJAGRO','GODREJCP','GODREJIND','GODREJPROP','GPPL','GRANULES','GRAPHITE','GRASIM',
                'GREAVESCOT','GREENLAM','GREENPLY','GRINDWELL','GRSE','GSFC','GSPL','GTPL','GUJALKALI','GUJGASLTD','GULFOILLUB',
                'HAL','HAPPSTMNDS','HATHWAY','HATSUN','HAVELLS','HCC','HCG','HCLTECH','HDFC','HDFCAMC','HDFCBANK','HDFCLIFE',
                'HEG','HEIDELBERG','HEMIPROP','HERANBA','HERITGFOOD','HEROMOTOCO','HESTERBIO','HFCL','HGINFRA','HIKAL','HIL',
                'HIMATSEIDE','HINDALCO','HINDCOPPER','HINDOILEXP','HINDPETRO','HINDUNILVR','HINDZINC','HOMEFIRST','HONAUT',
                'HSCL','HUDCO','HUHTAMAKI','IBREALEST','IBULHSGFIN','ICICIBANK','ICICIGI','ICICIPRULI','ICIL','ICRA','IDBI',
                'IDEA','IDFC','IDFCFIRSTB','IEX','IFBIND','IFCI','IGL','IGPL','IIFLSEC','IIFLWAM','IMFA','INDHOTEL','INDIACEM',
                'INDIAGLYCO','INDIAMART','INDIANB','INDIGO','INDIGOPNTS','INDOCO','INDOSTAR','INDUSINDBK','INDUSTOWER',
                'INEOSSTYRO','INFIBEAM','INFY','INGERRAND','INOXLEISUR','INOXWIND','INTELLECT','IOB','IOC','IOLCP','IPCALAB',
                'IRB','IRCON','IRCTC','IRFC','ISEC','ITC','ITDC','ITDCEM','ITI','J&KBANK','JAGRAN','JAICORPLTD','JAMNAAUTO',
                'JBCHEPHARM','JBMA','JCHAC','JINDALPOLY','JINDALSAW','JINDALSTEL','JKCEMENT','JKIL','JKLAKSHMI','JKPAPER',
                'JKTYRE','JMCPROJECT','JMFINANCIL','JPPOWER','JSL','JSLHISAR','JSWHL','JSWSTEEL','JTEKTINDIA','JUBLFOOD',
                'JUBLINGREA','JUBLPHARMA','JUSTDIAL','JYOTHYLAB','KAJARIACER','KALPATPOWR','KALYANKJIL','KANSAINER',
                'KARURVYSYA','KEC','KEI','KIOCL','KIRIINDUS','KIRLOSENG','KIRLOSIND','KNRCON','KOLTEPATIL','KOTAKBANK',
                'KPITTECH','KPRMILL','KRBL','KSB','KSCL','KSL','KTKBANK','L&TFH','LALPATHLAB','LAOPALA','LAURUSLABS',
                'LAXMIMACH','LEMONTREE','LICHSGFIN','LINDEINDIA','LT','LTI','LTTS','LUMAXIND','LUPIN','LUXIND','LXCHEM',
                'M&M','M&MFIN','MAHABANK','MAHINDCIE','MAHLIFE','MAHLOG','MAHSCOOTER','MAHSEAMLES','MAITHANALL','MANAPPURAM',
                'MARICO','MARKSANS','MARUTI','MASFIN','MASTEK','MATRIMONY','MAXHEALTH','MAYURUNIQ','MAZDOCK','MCDOWELL-N',
                'METROPOLIS','MFSL','MGL','MHRIL','MIDHANI','MINDACORP','MINDAIND','MINDTREE','MMFL','MMTC','MOIL','MOREPENLAB',
                'MOTHERSUMI','MOTILALOFS','MPHASIS','MRF','MRPL','MSTCLTD','MTARTECH','MTNL','MUTHOOTFIN','NAM-INDIA',
                'NATCOPHARM','NATIONALUM','NAUKRI','NAVINFLUOR','NAVNETEDUL','NAZARA','NBCC','NBVENTURES','NCC','NEOGEN',
                'NESCO','NETWORK18','NEWGEN','NFL','NH','NHPC','NIACL','NIITLTD','NILKAMAL','NLCINDIA','NMDC','NOCIL','NTPC',
                'NUCLEUS','OAL','OBEROIRLTY','OFSS','OIL','OMAXE','ONGC','ORIENTCEM','ORIENTELEC','ORISSAMINE','PAGEIND',
                'PAISALO','PCJEWELLER','PEL','PERSISTENT','PETRONET','PFC','PFIZER','PGHH','PGHL','PHOENIXLTD','PIDILITIND',
                'PIIND','PILANIINVS','PNB','PNCINFRA','POLYCAB','POLYMED','POLYPLEX','POWERGRID','POWERINDIA','PRAKASH',
                'PRESTIGE','PRINCEPIPE','PRIVISCL','PRSMJOHNSN','PSB','PSPPROJECT','PTC','PURVA','PVR','QUESS','QUICKHEAL',
                'RADICO','RAILTEL','RAIN','RAJESHEXPO','RALLIS','RAMCOCEM','RAMCOIND','RAMCOSYS','RATNAMANI','RAYMOND',
                'RBLBANK','RCF','RECLTD','REDINGTON','RELAXO','RELIANCE','RELIGARE','REPCOHOME','RESPONIND','RITES','RKFORGE',
                'ROSSARI','ROUTE','RSYSTEMS','RUCHI','RUPA','RVNL','SAFARI','SAGCEM','SAIL','SANDHAR','SANOFI','SASKEN',
                'SBICARD','SBILIFE','SBIN','SCHAEFFLER','SCHNEIDER','SCI','SEQUENT','SFL','SHARDACROP','SHILPAMED','SHK',
                'SHOPERSTOP','SHREECEM','SHRIRAMCIT','SIEMENS','SIS','SJVN','SKFINDIA','SOBHA','SOLARA','SOLARINDS',
                'SONATSOFTW','SOTL','SOUTHBANK','SPANDANA','SPARC','SRF','SRTRANSFIN','STAR','STARCEMENT','STLTECH',
                'STOVEKRAFT','SUBEXLTD','SUBROS','SUDARSCHEM','SUMICHEM','SUNCLAYLTD','SUNDARMFIN','SUNDRMFAST','SUNPHARMA',
                'SUNTECK','SUNTV','SUPRAJIT','SUPREMEIND','SURYAROSNI','SURYODAY','SUVENPHAR','SUVIDHAA','SUZLON',
                'SWANENERGY','SWARAJENG','SWSOLAR','SYMPHONY','SYNGENE','TASTYBITE','TATACHEM','TATACOFFEE','TATACOMM',
                'TATACONSUM','TATAELXSI','TATAINVEST','TATAMETALI','TATAMOTORS','TATAPOWER','TATASTEEL','TCI','TCIEXP',
                'TCNSBRANDS','TCS','TEAMLEASE','TECHM','TECHNOE','THERMAX','THOMASCOOK','THYROCARE','TIDEWATER','TIINDIA',
                'TIMETECHNO','TIMKEN','TINPLATE','TITAN','TORNTPHARM','TORNTPOWER','TRENT','TRITURBINE','TRIVENI','TTKPRESTIG',
                'TV18BRDCST','TVSMOTOR','TVSSRICHAK','TVTODAY','UBL','UCOBANK','UFLEX','UJJIVAN','UJJIVANSFB','ULTRACEMCO',
                'UNICHEMLAB','UNIONBANK','UPL','UTIAMC','VAIBHAVGBL','VAKRANGEE','VARROC','VBL','VEDL','VENKEYS','VESUVIUS',
                'VGUARD','VINATIORGA','VIPIND','VMART','VOLTAS','VRLLOG','VSTIND','VSTTILLERS','VTL','WABAG',
                'WELCORP','WELENT','WELSPUNIND','WHIRLPOOL','WIPRO','WOCKPHARMA','WSTCSTPAPR','YESBANK','ZEEL','ZENSARTECH',
                'ZYDUSWELL',]

# %%
def url(i) :
    return f'https://archives.nseindia.com/products/content/sec_bhavdata_full_{oldDate(i).strftime("%d%m%Y")}.csv'

def oldDate(n):
    return datetime.now() - timedelta(n)

def path(i,j):
    if j == 0:
        return f'P:/DEPROJECT/Raw_bhav_copy/Raw_bhavcopy_{oldDate(i).strftime("%Y-%m-%d")}.csv'
    else:
        return f'P:/DEPROJECT/Clean_bhav_copy/Clean_bhavcopy_{oldDate(i).strftime("%Y-%m-%d")}.csv'
    
def Comapny_file_path(name):
    return f'P:/DEPROJECT/Company_file/{name}.csv'

def Analyzed_company_file_path(name):
    return f'P:/DEPROJECT/Analyzed_Company_file/{name}.csv'

# %%
def rawdown(x):
    for i in (range(0,x)):
        try: 
            r = requests.get(url(i), timeout=1)
            print(f"Bhavcopy of {oldDate(i).strftime('%Y-%m-%d')} downloaded")
            df = pd.read_csv(url(i))
            df.to_csv(path(i,0),index=False)
        except requests.exceptions.Timeout as err: 
            pass
        
x = int(input("Enter Number of days back you want to perform operation: "))
rawdown(x)
# Out:
# Enter Number of days back you want to perform operation: 60
# Bhavcopy of 2022-05-15 downloaded
# Bhavcopy of 2022-05-13 downloaded
# Bhavcopy of 2022-05-12 downloaded
# Bhavcopy of 2022-05-11 downloaded
# Bhavcopy of 2022-05-10 downloaded
# Bhavcopy of 2022-05-09 downloaded
# Bhavcopy of 2022-05-08 downloaded
# Bhavcopy of 2022-05-06 downloaded
# Bhavcopy of 2022-05-05 downloaded
# Bhavcopy of 2022-05-04 downloaded
# Bhavcopy of 2022-05-03 downloaded
# Bhavcopy of 2022-05-02 downloaded
# Bhavcopy of 2022-05-01 downloaded
# Bhavcopy of 2022-04-29 downloaded
# Bhavcopy of 2022-04-28 downloaded
# Bhavcopy of 2022-04-27 downloaded
# Bhavcopy of 2022-04-26 downloaded
# Bhavcopy of 2022-04-25 downloaded
# Bhavcopy of 2022-04-24 downloaded
# Bhavcopy of 2022-04-22 downloaded
# Bhavcopy of 2022-04-21 downloaded
# Bhavcopy of 2022-04-20 downloaded
# Bhavcopy of 2022-04-19 downloaded
# Bhavcopy of 2022-04-18 downloaded
# Bhavcopy of 2022-04-17 downloaded
# Bhavcopy of 2022-04-15 downloaded
# Bhavcopy of 2022-04-14 downloaded
# Bhavcopy of 2022-04-13 downloaded
# Bhavcopy of 2022-04-12 downloaded
# Bhavcopy of 2022-04-11 downloaded
# Bhavcopy of 2022-04-10 downloaded
# Bhavcopy of 2022-04-08 downloaded
# Bhavcopy of 2022-04-07 downloaded
# Bhavcopy of 2022-04-06 downloaded
# Bhavcopy of 2022-04-05 downloaded
# Bhavcopy of 2022-04-04 downloaded
# Bhavcopy of 2022-04-01 downloaded
# Bhavcopy of 2022-03-31 downloaded
# Bhavcopy of 2022-03-30 downloaded
# Bhavcopy of 2022-03-29 downloaded
# Bhavcopy of 2022-03-28 downloaded
# Bhavcopy of 2022-03-27 downloaded
# Bhavcopy of 2022-03-25 downloaded
# Bhavcopy of 2022-03-24 downloaded
# Bhavcopy of 2022-03-23 downloaded
# Bhavcopy of 2022-03-22 downloaded
# Bhavcopy of 2022-03-21 downloaded
# Bhavcopy of 2022-03-20 downloaded
# Bhavcopy of 2022-03-18 downloaded

# %% [markdown]
# # CLEANING

# %%
for i in range(1,x):
    try:
        raw_df = pd.read_csv(path(i,0))

        #Reanming columns
        old_col_list = [' SYMBOL',' SERIES',' DATE1',' PREV_CLOSE',' OPEN_PRICE',' HIGH_PRICE',
                        ' LOW_PRICE',' LAST_PRICE',' CLOSE_PRICE',' AVG_PRICE',' TTL_TRD_QNTY',
                        ' TURNOVER_LACS',' NO_OF_TRADES',' DELIV_QTY',' DELIV_PER']

        for j in old_col_list: 
            raw_df.rename(columns = {j:j.strip()}, inplace = True)


        #Deleting 'Turnover_Lacs' column which is not needed 
        raw_df.drop('TURNOVER_LACS', axis=1, inplace=True) 
        raw_df.rename(columns={'DATE1':'DATE'}, inplace=True)


        # Keeping companies who comes under equity section
        raw_df = raw_df.loc[raw_df['SERIES'] == ' EQ'] 
        raw_df.reset_index(drop=True, inplace=True)
        
        # Creating temp datafrmae this data frame will keep records of company which are in our list 
        temp_df = pd.DataFrame()
        for z in Company_list:
            temp_df = temp_df.append(raw_df.loc[raw_df['SYMBOL'] == z], ignore_index=True) 
        print(f'{oldDate(i).strftime("%Y-%m-%d")} cleaned succesfully')
        # Saving clean temp_df to Local system in Clean_bhovcopy file 
        temp_df.to_csv(path(i,1),index=False)
    except:
        pass
# Out:
# 2022-05-15 cleaned succesfully
# 2022-05-13 cleaned succesfully
# 2022-05-12 cleaned succesfully
# 2022-05-11 cleaned succesfully
# 2022-05-10 cleaned succesfully
# 2022-05-09 cleaned succesfully
# 2022-05-08 cleaned succesfully
# 2022-05-06 cleaned succesfully
# 2022-05-05 cleaned succesfully
# 2022-05-04 cleaned succesfully
# 2022-05-03 cleaned succesfully
# 2022-05-02 cleaned succesfully
# 2022-05-01 cleaned succesfully
# 2022-04-29 cleaned succesfully
# 2022-04-28 cleaned succesfully
# 2022-04-27 cleaned succesfully
# 2022-04-26 cleaned succesfully
# 2022-04-25 cleaned succesfully
# 2022-04-24 cleaned succesfully
# 2022-04-22 cleaned succesfully
# 2022-04-21 cleaned succesfully
# 2022-04-20 cleaned succesfully
# 2022-04-19 cleaned succesfully
# 2022-04-18 cleaned succesfully
# 2022-04-17 cleaned succesfully
# 2022-04-15 cleaned succesfully
# 2022-04-14 cleaned succesfully
# 2022-04-13 cleaned succesfully
# 2022-04-12 cleaned succesfully
# 2022-04-11 cleaned succesfully
# 2022-04-10 cleaned succesfully
# 2022-04-08 cleaned succesfully
# 2022-04-07 cleaned succesfully
# 2022-04-06 cleaned succesfully
# 2022-04-05 cleaned succesfully
# 2022-04-04 cleaned succesfully
# 2022-04-01 cleaned succesfully
# 2022-03-31 cleaned succesfully
# 2022-03-30 cleaned succesfully
# 2022-03-29 cleaned succesfully
# 2022-03-28 cleaned succesfully
# 2022-03-27 cleaned succesfully
# 2022-03-25 cleaned succesfully
# 2022-03-24 cleaned succesfully
# 2022-03-23 cleaned succesfully
# 2022-03-22 cleaned succesfully
# 2022-03-21 cleaned succesfully
# 2022-03-20 cleaned succesfully
# 2022-03-18 cleaned succesfully

# %% [markdown]
# # SPLITTING

# %%
COLUMN_NAMES = ['SYMBOL','SERIES','DATE','PREV_CLOSE','OPEN_PRICE','HIGH_PRICE','LOW_PRICE','LAST_PRICE',
                'CLOSE_PRICE','AVG_PRICE','TTL_TRD_QNTY','NO_OF_TRADES','DELIV_QTY','DELIV_PER','DELIV_VALUE',
                '5DDeVA','%Change_In_Price','%Change_In_Deliv_vs_AVG','Intraday_volume']
for i in Company_list:
    df = pd.DataFrame(columns=COLUMN_NAMES)
    df.to_csv(f'P:/DEPROJECT/Company_file/{i}.csv',index=False)

# %%
for i in reversed(range(0,x)):
    try:
        df = pd.read_csv(path(i,1))
        print(oldDate(i).strftime("%Y-%m-%d"))
        for i in Company_list:
            # Loading companys csv file in program 
            company_df = pd.read_csv(Comapny_file_path(i))
            
            # Finding comapnys row from clean bhav copy 
            temp_df = df[df['SYMBOL']== i]

            # Adding companys now to company's csv file 
            company_df = pd.concat([company_df, temp_df], ignore_index = True, axis = 0)

            company_df.drop_duplicates(subset ="DATE",keep = "last", inplace = True,ignore_index= True)    
            company_df.to_csv(Comapny_file_path(i), index=False)
    except:
        print(f'{oldDate(i).strftime("%Y-%m-%d")} --> no data')
# Out:
# 2022-03-18
# 2022-03-19 --> no data
# 2022-03-20
# 2022-03-21
# 2022-03-22
# 2022-03-23
# 2022-03-24
# 2022-03-25
# 2022-03-26 --> no data
# 2022-03-27
# 2022-03-28
# 2022-03-29
# 2022-03-30
# 2022-03-31
# 2022-04-01
# 2022-04-02 --> no data
# 2022-04-03 --> no data
# 2022-04-04
# 2022-04-05
# 2022-04-06
# 2022-04-07
# 2022-04-08
# 2022-04-09 --> no data
# 2022-04-10
# 2022-04-11
# 2022-04-12
# 2022-04-13
# 2022-04-14
# 2022-04-15
# 2022-04-16 --> no data
# 2022-04-17
# 2022-04-18
# 2022-04-19
# 2022-04-20
# 2022-04-21
# 2022-04-22
# 2022-04-23 --> no data
# 2022-04-24
# 2022-04-25
NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN
#    SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  \
# 37    VTL     EQ   13-May-2022       318.5       322.0       326.7      309.0
#
#     LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  DELIV_QTY  \
# 37       309.9        310.4     318.27        646801         21213     259068
#
#     DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  %Change_In_Deliv_vs_AVG  \
# 37      40.05          NaN     NaN               NaN                      NaN
#
#     Intraday_volume
# 37              NaN
#    SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  \
# 37  WABAG     EQ   13-May-2022      236.55       247.5       249.8     237.25
#
#     LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  DELIV_QTY  \
# 37       240.0        239.9     240.83        129648          6254      58357
#
#     DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  %Change_In_Deliv_vs_AVG  \
# 37      45.01          NaN     NaN               NaN                      NaN
#
#     Intraday_volume
# 37              NaN
#      SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 37  WELCORP     EQ   13-May-2022      167.45       172.0       180.9
#
#     LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  \
# 37      171.0       178.0        178.1     177.83        983438         22384
#
#     DELIV_QTY  DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  \
# 37     432837      44.01          NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN
#     SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 37  WELENT     EQ   13-May-2022       70.55        74.0       84.65
#
#     LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  \
# 37       74.0        76.0        75.95      78.82        742724         12211
#
#     DELIV_QTY  DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  \
# 37     147157      19.81          NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN
#         SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 37  WELSPUNIND     EQ   13-May-2022       66.05        68.4       68.55
#
#     LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  \
# 37       64.7       67.75         67.4      66.65       4879534         38828
#
#     DELIV_QTY  DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  \
# 37    1278845      26.21          NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN
#        SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 37  WHIRLPOOL     EQ   13-May-2022     1559.15      1562.0     1593.45
#
#     LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  \
# 37     1551.2      1552.4      1554.65    1576.97         65292          4798
#
#     DELIV_QTY  DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  \
# 37      24029       36.8          NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN
#    SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  \
# 37  WIPRO     EQ   13-May-2022       473.8       479.5       479.5      467.0
#
#     LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  DELIV_QTY  \
# 37       468.8       468.65     472.26       8387659        203118    3751197
#
#     DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  %Change_In_Deliv_vs_AVG  \
# 37      44.72          NaN     NaN               NaN                      NaN
#
#     Intraday_volume
# 37              NaN
#         SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 37  WOCKPHARMA     EQ   13-May-2022       230.4       234.9       241.7
#
#     LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  \
# 37      230.5      237.65       234.65     235.75        354458          9579
#
#     DELIV_QTY  DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  \
# 37     121280      34.22          NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN
#         SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 37  WSTCSTPAPR     EQ   13-May-2022       305.2       315.0       320.6
#
#     LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  \
# 37      306.0       310.0       308.85     313.12        196140          4998
#
#     DELIV_QTY  DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  \
# 37      85622      43.65          NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN
#      SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 37  YESBANK     EQ   13-May-2022       12.55        12.7       12.85
#
#     LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  \
# 37      12.45        12.5        12.45      12.63      69982971         70117
#
#     DELIV_QTY  DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  \
# 37   27030980      38.63          NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN
#    SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  \
# 37   ZEEL     EQ   13-May-2022      236.25      239.05       247.5     237.55
#
#     LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  DELIV_QTY  \
# 37       239.9       239.25     243.56       9029271         59153    1888308
#
#     DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  %Change_In_Deliv_vs_AVG  \
# 37      20.91          NaN     NaN               NaN                      NaN
#
#     Intraday_volume
# 37              NaN
#         SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 37  ZENSARTECH     EQ   13-May-2022       305.6       315.0       317.0
#
#     LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  \
# 37     300.05       301.9        302.2     304.65        974429         37946
#
#     DELIV_QTY  DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  \
# 37     449376      46.12          NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN
#        SYMBOL SERIES          DATE  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 37  ZYDUSWELL     EQ   13-May-2022     1528.75      1569.0     1603.95
#
#     LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  NO_OF_TRADES  \
# 37     1540.3      1581.0      1583.35    1583.65         25772          6308
#
#     DELIV_QTY  DELIV_PER  DELIV_VALUE  5DDeVA  %Change_In_Price  \
# 37      14921       57.9          NaN     NaN               NaN
#
#     %Change_In_Deliv_vs_AVG  Intraday_volume
# 37                      NaN              NaN

# %%
# # Checking companys data are in their respitcive comapnys file

# for i in Company_list:

#     # Reading comapny csv file 
#     company_df = pd.read_csv(Comapny_file_path(i))

#     # Finding number of unique values in comapny's file Symbol this helps that an 
#     aa = len(set(list(company_df["SYMBOL"])))

#     if i != company_df.at[ 0, "SYMBOL"] or aa >=2: 
#         print(i, company_df.at[0,'SYMBOL'])

# %% [markdown]
# # Analyzing company file starts from here

# %%
def analyzer(df):

    df["DELIV_VALUE"] = ''
    df["5DDeVA"] = ''
    df['%Change_In_Price'] = ''
    df['%Change_In_Deliv_vs_AVG'] = ''
    df["DELIV_VALUE"]= (df['DELIV_QTY'] * df['AVG_PRICE']) / 10000000

    for i in range (5):
        df['5DDeVA'][i] = np.nan
        df['%Change_In_Price'][i] = np.nan
        df['%Change_In_Deliv_vs_AVG'][i] = np.nan
        df['Intraday_volume'] = np.nan

    for i in range (5, df.shape [0]):
        df.at[i,'5DDeVA'] = df["DELIV_VALUE"].iloc[i-5:i].mean()
        df.at[i,'%Change_In_Price'] = ((df.at[i,'CLOSE_PRICE']-df.at[i-1,'CLOSE_PRICE'])/df.at[i-1,'CLOSE_PRICE']) * 100
        df.at[i,'%Change_In_Deliv_vs_AVG'] = (df.at[i, 'DELIV_VALUE']/df.at[i, '5DDeVA']) * 100 
        df.at[i,'Intraday_volume'] = int(df.at[i,'TTL_TRD_QNTY']-df.at[i,"DELIV_QTY"])

    return df

# %%
for company in Company_list:

    df = pd.read_csv(Comapny_file_path(company))

    analyzer(df).to_csv(Analyzed_company_file_path(company), index=False)
    print(f'{company} file analyzed')
# Out:
# 3MINDIA file analyzed
# AARTIDRUGS file analyzed
# AARTIIND file analyzed
# AAVAS file analyzed
# ABB file analyzed
# ABCAPITAL file analyzed
# ABFRL file analyzed
# ACC file analyzed
# ACCELYA file analyzed
# ACE file analyzed
# ADANIENT file analyzed
# ADANIPORTS file analyzed
# ADFFOODS file analyzed
# ADVENZYMES file analyzed
# AEGISCHEM file analyzed
# AHLUCONT file analyzed
# AIAENG file analyzed
# AJANTPHARM file analyzed
# AKZOINDIA file analyzed
# ALEMBICLTD file analyzed
# ALKEM file analyzed
# ALKYLAMINE file analyzed
# ALLCARGO file analyzed
# ALOKINDS file analyzed
# AMARAJABAT file analyzed
# AMBER file analyzed
# AMBUJACEM file analyzed
# AMRUTANJAN file analyzed
# ANURAS file analyzed
# APARINDS file analyzed
# APLAPOLLO file analyzed
# APLLTD file analyzed
# APOLLOHOSP file analyzed
# APOLLOPIPE file analyzed
# APOLLOTYRE file analyzed
# ARVIND file analyzed
# ARVINDFASN file analyzed
# ASAHIINDIA file analyzed
# ASHIANA file analyzed
# ASHOKA file analyzed
# ASHOKLEY file analyzed
# ASIANPAINT file analyzed
# ASTEC file analyzed
# ASTERDM file analyzed
# ASTRAL file analyzed
# ASTRAZEN file analyzed
# ATFL file analyzed
# ATUL file analyzed
# AUBANK file analyzed
# AUROPHARMA file analyzed
# AUTOAXLES file analyzed
# AVANTIFEED file analyzed
# AXISBANK file analyzed
# BAJAJ-AUTO file analyzed
# BAJAJCON file analyzed
# BAJAJELEC file analyzed
# BAJAJFINSV file analyzed
# BAJAJHLDNG file analyzed
# BAJFINANCE file analyzed
# BALAMINES file analyzed
# BALKRISIND file analyzed
# BALMLAWRIE file analyzed
# BALRAMCHIN file analyzed
# BANARISUG file analyzed
# BANDHANBNK file analyzed
# BANKBARODA file analyzed
# BANKINDIA file analyzed
# BASF file analyzed
# BATAINDIA file analyzed
# BBTC file analyzed
# BDL file analyzed
# BECTORFOOD file analyzed
# BEL file analyzed
# BEML file analyzed
# BEPL file analyzed
# BERGEPAINT file analyzed
# BHARATFORG file analyzed
# BHARATRAS file analyzed
# BHARTIARTL file analyzed
# BHEL file analyzed
# BIOCON file analyzed
# BIRLACORPN file analyzed
# BLUEDART file analyzed
# BLUESTARCO file analyzed
# BOMDYEING file analyzed
# BOSCHLTD file analyzed
# BPCL file analyzed
# BRIGADE file analyzed
# BRITANNIA file analyzed
# BSE file analyzed
# BSOFT file analyzed
# CAMLINFINE file analyzed
# CANBK file analyzed
# CANFINHOME file analyzed
# CAPACITE file analyzed
# CAPLIPOINT file analyzed
# CARBORUNIV file analyzed
# CARERATING file analyzed
# CASTROLIND file analyzed
# CCL file analyzed
# CDSL file analyzed
# CEATLTD file analyzed
# CENTRALBK file analyzed
# CENTRUM file analyzed
# CENTURYPLY file analyzed
# CENTURYTEX file analyzed
# CERA file analyzed
# CESC file analyzed
# CGCL file analyzed
# CHALET file analyzed
# CHAMBLFERT file analyzed
# CHEMCON file analyzed
# CHENNPETRO file analyzed
# CHOLAFIN file analyzed
# CHOLAHLDNG file analyzed
# CIPLA file analyzed
# COALINDIA file analyzed
# COCHINSHIP file analyzed
# COFORGE file analyzed
# COLPAL file analyzed
# CONCOR file analyzed
# CONFIPET file analyzed
# COROMANDEL file analyzed
# CRAFTSMAN file analyzed
# CREDITACC file analyzed
# CRISIL file analyzed
# CROMPTON file analyzed
# CSBBANK file analyzed
# CUB file analyzed
# CUMMINSIND file analyzed
# CYIENT file analyzed
# DAAWAT file analyzed
# DABUR file analyzed
# DALBHARAT file analyzed
# DALMIASUG file analyzed
# DBCORP file analyzed
# DBL file analyzed
# DCAL file analyzed
# DCBBANK file analyzed
# DCMSHRIRAM file analyzed
# DEEPAKNTR file analyzed
# DELTACORP file analyzed
# DEN file analyzed
# DFMFOODS file analyzed
# DHAMPURSUG file analyzed
# DHANI file analyzed
# DHANUKA file analyzed
# DIAMONDYD file analyzed
# DISHTV file analyzed
# DIVISLAB file analyzed
# DIXON file analyzed
# DLF file analyzed
# DMART file analyzed
# DOLLAR file analyzed
# DRREDDY file analyzed
# EASEMYTRIP file analyzed
# EDELWEISS file analyzed
# EICHERMOT file analyzed
# EIDPARRY file analyzed
# EIHOTEL file analyzed
# ELGIEQUIP file analyzed
# EMAMILTD file analyzed
# ENDURANCE file analyzed
# ENGINERSIN file analyzed
# EPL file analyzed
# EQUITAS file analyzed
# EQUITASBNK file analyzed
# ERIS file analyzed
# ESABINDIA file analyzed
# ESCORTS file analyzed
# EVEREADY file analyzed
# EXIDEIND file analyzed
# FACT file analyzed
# FCONSUMER file analyzed
# FDC file analyzed
# FEDERALBNK file analyzed
# FILATEX file analyzed
# FINCABLES file analyzed
# FINEORG file analyzed
# FINPIPE file analyzed
# FMGOETZE file analyzed
# FORTIS file analyzed
# FRETAIL file analyzed
# FSL file analyzed
# GABRIEL file analyzed
# GAEL file analyzed
# GAIL file analyzed
# GALAXYSURF file analyzed
# GANECOS file analyzed
# GARFIBRES file analyzed
# GATI file analyzed
# GENUSPOWER file analyzed
# GEOJITFSL file analyzed
# GEPIL file analyzed
# GESHIP file analyzed
# GET&D file analyzed
# GHCL file analyzed
# GICRE file analyzed
# GILLETTE file analyzed
# GLAND file analyzed
# GLAXO file analyzed
# GLENMARK file analyzed
# GMDCLTD file analyzed
# GMMPFAUDLR file analyzed
# GMRINFRA file analyzed
# GNFC file analyzed
# GODFRYPHLP file analyzed
# GODREJAGRO file analyzed
# GODREJCP file analyzed
# GODREJIND file analyzed
# GODREJPROP file analyzed
# GPPL file analyzed
# GRANULES file analyzed
# GRAPHITE file analyzed
# GRASIM file analyzed
# GREAVESCOT file analyzed
# GREENLAM file analyzed
# GREENPLY file analyzed
# GRINDWELL file analyzed
# GRSE file analyzed
# GSFC file analyzed
# GSPL file analyzed
# GTPL file analyzed
# GUJALKALI file analyzed
# GUJGASLTD file analyzed
# GULFOILLUB file analyzed
# HAL file analyzed
# HAPPSTMNDS file analyzed
# HATHWAY file analyzed
# HATSUN file analyzed
# HAVELLS file analyzed
# HCC file analyzed
# HCG file analyzed
# HCLTECH file analyzed
# HDFC file analyzed
# HDFCAMC file analyzed
# HDFCBANK file analyzed
# HDFCLIFE file analyzed
# HEG file analyzed
# HEIDELBERG file analyzed
# HEMIPROP file analyzed
# HERANBA file analyzed
# HERITGFOOD file analyzed
# HEROMOTOCO file analyzed
# HESTERBIO file analyzed
# HFCL file analyzed
# HGINFRA file analyzed
# HIKAL file analyzed
# HIL file analyzed
# HIMATSEIDE file analyzed
# HINDALCO file analyzed
# HINDCOPPER file analyzed
# HINDOILEXP file analyzed
# HINDPETRO file analyzed
# HINDUNILVR file analyzed
# HINDZINC file analyzed
# HOMEFIRST file analyzed
# HONAUT file analyzed
# HSCL file analyzed
# HUDCO file analyzed
# HUHTAMAKI file analyzed
# IBREALEST file analyzed
# IBULHSGFIN file analyzed
# ICICIBANK file analyzed
# ICICIGI file analyzed
# ICICIPRULI file analyzed
# ICIL file analyzed
# ICRA file analyzed
# IDBI file analyzed
# IDEA file analyzed
# IDFC file analyzed
# IDFCFIRSTB file analyzed
# IEX file analyzed
# IFBIND file analyzed
# IFCI file analyzed
# IGL file analyzed
# IGPL file analyzed
# IIFLSEC file analyzed
# IIFLWAM file analyzed
# IMFA file analyzed
# INDHOTEL file analyzed
# INDIACEM file analyzed
# INDIAGLYCO file analyzed
# INDIAMART file analyzed
# INDIANB file analyzed
# INDIGO file analyzed
# INDIGOPNTS file analyzed
# INDOCO file analyzed
# INDOSTAR file analyzed
# INDUSINDBK file analyzed
# INDUSTOWER file analyzed
# INEOSSTYRO file analyzed
# INFIBEAM file analyzed
# INFY file analyzed
# INGERRAND file analyzed
# INOXLEISUR file analyzed
# INOXWIND file analyzed
# INTELLECT file analyzed
# IOB file analyzed
# IOC file analyzed
# IOLCP file analyzed
# IPCALAB file analyzed
# IRB file analyzed
# IRCON file analyzed
# IRCTC file analyzed
# IRFC file analyzed
# ISEC file analyzed
# ITC file analyzed
# ITDC file analyzed
# ITDCEM file analyzed
# ITI file analyzed
# J&KBANK file analyzed
# JAGRAN file analyzed
# JAICORPLTD file analyzed
# JAMNAAUTO file analyzed
# JBCHEPHARM file analyzed
# JBMA file analyzed
# JCHAC file analyzed
# JINDALPOLY file analyzed
# JINDALSAW file analyzed
# JINDALSTEL file analyzed
# JKCEMENT file analyzed
# JKIL file analyzed
# JKLAKSHMI file analyzed
# JKPAPER file analyzed
# JKTYRE file analyzed
# JMCPROJECT file analyzed
# JMFINANCIL file analyzed
# JPPOWER file analyzed
# JSL file analyzed
# JSLHISAR file analyzed
# JSWHL file analyzed
# JSWSTEEL file analyzed
# JTEKTINDIA file analyzed
# JUBLFOOD file analyzed
# JUBLINGREA file analyzed
# JUBLPHARMA file analyzed
# JUSTDIAL file analyzed
# JYOTHYLAB file analyzed
# KAJARIACER file analyzed
# KALPATPOWR file analyzed
# KALYANKJIL file analyzed
# KANSAINER file analyzed
# KARURVYSYA file analyzed
# KEC file analyzed
# KEI file analyzed
# KIOCL file analyzed
# KIRIINDUS file analyzed
# KIRLOSENG file analyzed
# KIRLOSIND file analyzed
# KNRCON file analyzed
# KOLTEPATIL file analyzed
# KOTAKBANK file analyzed
# KPITTECH file analyzed
# KPRMILL file analyzed
# KRBL file analyzed
# KSB file analyzed
# KSCL file analyzed
# KSL file analyzed
# KTKBANK file analyzed
# L&TFH file analyzed
# LALPATHLAB file analyzed
# LAOPALA file analyzed
# LAURUSLABS file analyzed
# LAXMIMACH file analyzed
# LEMONTREE file analyzed
# LICHSGFIN file analyzed
# LINDEINDIA file analyzed
# LT file analyzed
# LTI file analyzed
# LTTS file analyzed
# LUMAXIND file analyzed
# LUPIN file analyzed
# LUXIND file analyzed
# LXCHEM file analyzed
# M&M file analyzed
# M&MFIN file analyzed
# MAHABANK file analyzed
# MAHINDCIE file analyzed
# MAHLIFE file analyzed
# MAHLOG file analyzed
# MAHSCOOTER file analyzed
# MAHSEAMLES file analyzed
# MAITHANALL file analyzed
# MANAPPURAM file analyzed
# MARICO file analyzed
# MARKSANS file analyzed
# MARUTI file analyzed
# MASFIN file analyzed
# MASTEK file analyzed
# MATRIMONY file analyzed
# MAXHEALTH file analyzed
# MAYURUNIQ file analyzed
# MAZDOCK file analyzed
# MCDOWELL-N file analyzed
# METROPOLIS file analyzed
# MFSL file analyzed
# MGL file analyzed
# MHRIL file analyzed
# MIDHANI file analyzed
# MINDACORP file analyzed
# MINDAIND file analyzed
# MINDTREE file analyzed
# MMFL file analyzed
# MMTC file analyzed
# MOIL file analyzed
# MOREPENLAB file analyzed
# MOTHERSUMI file analyzed
# MOTILALOFS file analyzed
# MPHASIS file analyzed
# MRF file analyzed
# MRPL file analyzed
# MSTCLTD file analyzed
# MTARTECH file analyzed
# MTNL file analyzed
# MUTHOOTFIN file analyzed
# NAM-INDIA file analyzed
# NATCOPHARM file analyzed
# NATIONALUM file analyzed
# NAUKRI file analyzed
# NAVINFLUOR file analyzed
# NAVNETEDUL file analyzed
# NAZARA file analyzed
# NBCC file analyzed
# NBVENTURES file analyzed
# NCC file analyzed
# NEOGEN file analyzed
# NESCO file analyzed
# NETWORK18 file analyzed
# NEWGEN file analyzed
# NFL file analyzed
# NH file analyzed
# NHPC file analyzed
# NIACL file analyzed
# NIITLTD file analyzed
# NILKAMAL file analyzed
# NLCINDIA file analyzed
# NMDC file analyzed
# NOCIL file analyzed
# NTPC file analyzed
# NUCLEUS file analyzed
# OAL file analyzed
# OBEROIRLTY file analyzed
# OFSS file analyzed
# OIL file analyzed
# OMAXE file analyzed
# ONGC file analyzed
# ORIENTCEM file analyzed
# ORIENTELEC file analyzed
# ORISSAMINE file analyzed
# PAGEIND file analyzed
# PAISALO file analyzed
# PCJEWELLER file analyzed
# PEL file analyzed
# PERSISTENT file analyzed
# PETRONET file analyzed
# PFC file analyzed
# PFIZER file analyzed
# PGHH file analyzed
# PGHL file analyzed
# PHOENIXLTD file analyzed
# PIDILITIND file analyzed
# PIIND file analyzed
# PILANIINVS file analyzed
# PNB file analyzed
# PNCINFRA file analyzed
# POLYCAB file analyzed
# POLYMED file analyzed
# POLYPLEX file analyzed
# POWERGRID file analyzed
# POWERINDIA file analyzed
# PRAKASH file analyzed
# PRESTIGE file analyzed
# PRINCEPIPE file analyzed
# PRIVISCL file analyzed
# PRSMJOHNSN file analyzed
# PSB file analyzed
# PSPPROJECT file analyzed
# PTC file analyzed
# PURVA file analyzed
# PVR file analyzed
# QUESS file analyzed
# QUICKHEAL file analyzed
# RADICO file analyzed
# RAILTEL file analyzed
# RAIN file analyzed
# RAJESHEXPO file analyzed
# RALLIS file analyzed
# RAMCOCEM file analyzed
# RAMCOIND file analyzed
# RAMCOSYS file analyzed
# RATNAMANI file analyzed
# RAYMOND file analyzed
# RBLBANK file analyzed
# RCF file analyzed
# RECLTD file analyzed
# REDINGTON file analyzed
# RELAXO file analyzed
# RELIANCE file analyzed
# RELIGARE file analyzed
# REPCOHOME file analyzed
# RESPONIND file analyzed
# RITES file analyzed
# RKFORGE file analyzed
# ROSSARI file analyzed
# ROUTE file analyzed
# RSYSTEMS file analyzed
# RUCHI file analyzed
# RUPA file analyzed
# RVNL file analyzed
# SAFARI file analyzed
# SAGCEM file analyzed
# SAIL file analyzed
# SANDHAR file analyzed
# SANOFI file analyzed
# SASKEN file analyzed
# SBICARD file analyzed
# SBILIFE file analyzed
# SBIN file analyzed
# SCHAEFFLER file analyzed
# SCHNEIDER file analyzed
# SCI file analyzed
# SEQUENT file analyzed
# SFL file analyzed
# SHARDACROP file analyzed
# SHILPAMED file analyzed
# SHK file analyzed
# SHOPERSTOP file analyzed
# SHREECEM file analyzed
# SHRIRAMCIT file analyzed
# SIEMENS file analyzed
# SIS file analyzed
# SJVN file analyzed
# SKFINDIA file analyzed
# SOBHA file analyzed
# SOLARA file analyzed
# SOLARINDS file analyzed
# SONATSOFTW file analyzed
# SOTL file analyzed
# SOUTHBANK file analyzed
# SPANDANA file analyzed
# SPARC file analyzed
# SRF file analyzed
# SRTRANSFIN file analyzed
# STAR file analyzed
# STARCEMENT file analyzed
# STLTECH file analyzed
# STOVEKRAFT file analyzed
# SUBEXLTD file analyzed
# SUBROS file analyzed
# SUDARSCHEM file analyzed
# SUMICHEM file analyzed
# SUNCLAYLTD file analyzed
# SUNDARMFIN file analyzed
# SUNDRMFAST file analyzed
# SUNPHARMA file analyzed
# SUNTECK file analyzed
# SUNTV file analyzed
# SUPRAJIT file analyzed
# SUPREMEIND file analyzed
# SURYAROSNI file analyzed
# SURYODAY file analyzed
# SUVENPHAR file analyzed
# SUVIDHAA file analyzed
# SUZLON file analyzed
# SWANENERGY file analyzed
# SWARAJENG file analyzed
# SWSOLAR file analyzed
# SYMPHONY file analyzed
# SYNGENE file analyzed
# TASTYBITE file analyzed
# TATACHEM file analyzed
# TATACOFFEE file analyzed
# TATACOMM file analyzed
# TATACONSUM file analyzed
# TATAELXSI file analyzed
# TATAINVEST file analyzed
# TATAMETALI file analyzed
# TATAMOTORS file analyzed
# TATAPOWER file analyzed
# TATASTEEL file analyzed
# TCI file analyzed
# TCIEXP file analyzed
# TCNSBRANDS file analyzed
# TCS file analyzed
# TEAMLEASE file analyzed
# TECHM file analyzed
# TECHNOE file analyzed
# THERMAX file analyzed
# THOMASCOOK file analyzed
# THYROCARE file analyzed
# TIDEWATER file analyzed
# TIINDIA file analyzed
# TIMETECHNO file analyzed
# TIMKEN file analyzed
# TINPLATE file analyzed
# TITAN file analyzed
# TORNTPHARM file analyzed
# TORNTPOWER file analyzed
# TRENT file analyzed
# TRITURBINE file analyzed
# TRIVENI file analyzed
# TTKPRESTIG file analyzed
# TV18BRDCST file analyzed
# TVSMOTOR file analyzed
# TVSSRICHAK file analyzed
# TVTODAY file analyzed
# UBL file analyzed
# UCOBANK file analyzed
# UFLEX file analyzed
# UJJIVAN file analyzed
# UJJIVANSFB file analyzed
# ULTRACEMCO file analyzed
# UNICHEMLAB file analyzed
# UNIONBANK file analyzed
# UPL file analyzed
# UTIAMC file analyzed
# VAIBHAVGBL file analyzed
# VAKRANGEE file analyzed
# VARROC file analyzed
# VBL file analyzed
# VEDL file analyzed
# VENKEYS file analyzed
# VESUVIUS file analyzed
# VGUARD file analyzed
# VINATIORGA file analyzed
# VIPIND file analyzed
# VMART file analyzed
# VOLTAS file analyzed
# VRLLOG file analyzed
# VSTIND file analyzed
# VSTTILLERS file analyzed
# VTL file analyzed
# WABAG file analyzed
# WELCORP file analyzed
# WELENT file analyzed
# WELSPUNIND file analyzed
# WHIRLPOOL file analyzed
# WIPRO file analyzed
# WOCKPHARMA file analyzed
# WSTCSTPAPR file analyzed
# YESBANK file analyzed
# ZEEL file analyzed
# ZENSARTECH file analyzed
# ZYDUSWELL file analyzed
